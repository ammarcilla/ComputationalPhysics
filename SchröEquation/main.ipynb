# %% [markdown]
# # TEORIA
# Ec de Schrodinger:
# $H \psi = E \psi$
#
# Operador H en 2D:
# ![image.png](attachment:image.png)
#
# $\psi$ es una función si tratamos el problema de forma analítica (un vector de infinitas componentes). Si dicretizamos el espacio $\psi$ se convierte en un vector. EN nuestro espacio 2D, $\psi$ toma un valor en cada punto luego tenemos NxN valores de $\psi$. Para tratarlo como un vector tomamos cada columna de N valores y la emplamamos con la siguiente en vertical construyendo un vector de NxN componentes.

# %%
import numpy as np


# RESOLVEMOS EN 2D

N = 400
X, Y = np.mgrid[0:1:N*1j, 0:1:N*1j]
X
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.00250627, 0.00250627, 0.00250627, ..., 0.00250627, 0.00250627,
#         0.00250627],
#        [0.00501253, 0.00501253, 0.00501253, ..., 0.00501253, 0.00501253,
#         0.00501253],
#        ...,
#        [0.99498747, 0.99498747, 0.99498747, ..., 0.99498747, 0.99498747,
#         0.99498747],
#        [0.99749373, 0.99749373, 0.99749373, ..., 0.99749373, 0.99749373,
#         0.99749373],
#        [1.        , 1.        , 1.        , ..., 1.        , 1.        ,
#         1.        ]], shape=(400, 400))
